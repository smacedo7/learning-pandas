# %%
import pandas as pd
import json

# %%
caminho = '/Users/samuelmacedo/Downloads/dados.json'

# %%
df = pd.read_json(caminho)

# %%
df
# Out:
#                                              pessoas
# 0  {'nome': 'João', 'idade': '25', 'endereco': {'...
# 1  {'nome': 'Maria', 'idade': 30, 'endereco': {'r...

# %%
with open(caminho) as f:
    json_bruto = json.load(f)

# %%
json_bruto
# Out:
# {'pessoas': [{'nome': 'João',
#    'idade': '25',
#    'endereco': {'rua': 'Rua A', 'numero': 123, 'cidade': 'São Paulo'},
#    'telefones': ['11 1111-1111', '11 2222-2222']},
#   {'nome': 'Maria',
#    'idade': 30,
#    'endereco': {'rua': '', 'numero': 456, 'cidade': 'Rio de Janeiro'},
#    'telefones': ['21 3333-3333']}]}

# %%
df_normalizado = pd.json_normalize(json_bruto, record_path=['pessoas'])

# %%
df_normalizado
# Out:
#     nome idade                     telefones endereco.rua  endereco.numero  \
# 0   João    25  [11 1111-1111, 11 2222-2222]        Rua A              123
# 1  Maria    30                [21 3333-3333]                           456
#
#   endereco.cidade
# 0       São Paulo
# 1  Rio de Janeiro

# %%
df_normalizado.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nome             2 non-null      str
#  1   idade            2 non-null      object
#  2   telefones        2 non-null      object
#  3   endereco.rua     2 non-null      str
#  4   endereco.numero  2 non-null      int64
#  5   endereco.cidade  2 non-null      str
# dtypes: int64(1), object(2), str(3)
# memory usage: 228.0+ bytes

# %%
df_normalizado['idade'] = df_normalizado["idade"].astype(int)

# %%
df_normalizado.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nome             2 non-null      str
#  1   idade            2 non-null      int64
#  2   telefones        2 non-null      object
#  3   endereco.rua     2 non-null      str
#  4   endereco.numero  2 non-null      int64
#  5   endereco.cidade  2 non-null      str
# dtypes: int64(2), object(1), str(3)
# memory usage: 228.0+ bytes

# %%
df_normalizado[df_normalizado["endereco.rua"] != '']
# Out:
#    nome  idade                     telefones endereco.rua  endereco.numero  \
# 0  João     25  [11 1111-1111, 11 2222-2222]        Rua A              123
#
#   endereco.cidade
# 0       São Paulo

# %%
df_filtrado = df_normalizado[df_normalizado["endereco.rua"] != '']
