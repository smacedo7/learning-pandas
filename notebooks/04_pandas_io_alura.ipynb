# %%
import pandas as pd
from pathlib import Path
from IPython.display import display

# %%
caminho = Path.home() / "Downloads" / "filmes_wikipedia.html"

print(caminho)
print("Existe?", caminho.exists())

print("\nArquivos parecidos:")
for arquivo in (Path.home() / "Downloads").glob("filmes*"):
    print(repr(arquivo.name))

dados_html = pd.read_html(caminho)

print(len(dados_html))
display(dados_html[0])
# Out:
# /Users/samuelmacedo/Downloads/filmes_wikipedia.html
# Existe? True
#
# Arquivos parecidos:
# 'filmes_wikipedia.html'
# 3
#        0                      1
# 0   1998             100 Movies
# 1   1999              100 Stars
# 2   2000             100 Laughs
# 3   2001            100 Thrills
# 4   2002           100 Passions
# 5   2003  100 Heroes & Villains
# 6   2004              100 Songs
# 7   2005       100 Movie Quotes
# 8   2005              25 Scores
# 9   2006             100 Cheers
# 10  2006            25 Musicals
# 11  2007   100 Movies (Updated)
# 12  2008        AFI's 10 Top 10
# 13   vte                    vte

# %%
caminho = Path.home() / "Donwloads" / "filmes_wikipedia.html"
dados_html = pd.read_html(caminho)
display(dados_html[0])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/Projetos/Pandas/.venv/lib/python3.14/site-packages/pandas/io/html.py:794, in _LxmlFrameParser._build_doc(self)
#     793 try:
# --> 794     r = parse(self.io, parser=parser)
#     795 except OSError as err:
#
# File ~/Projetos/Pandas/.venv/lib/python3.14/site-packages/lxml/html/__init__.py:918, in parse(filename_or_url, parser, base_url, **kw)
#     917     parser = html_parser
# --> 918 return etree.parse(filename_or_url, parser, base_url=base_url, **kw)
#
# File src/lxml/etree.pyx:3717, in lxml.etree.parse()
# -> 3717 'Could not get source, probably due dynamically evaluated source code.'
#
# File src/lxml/parser.pxi:2045, in lxml.etree._parseDocument()
# -> 2045 'Could not get source, probably due dynamically evaluated source code.'
#
# File src/lxml/parser.pxi:2071, in lxml.etree._parseDocumentFromURL()
# ...
